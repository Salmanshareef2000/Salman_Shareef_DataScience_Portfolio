# %%
# !pip install vaderSentiment

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
chunks = pd.read_csv(
    "../data/mental_health_reddit_clean.csv",
    chunksize=20000
)

# %%
output_path = "../data/mental_health_reddit_with_sentiment.csv"

first_chunk = True

for i, chunk in enumerate(chunks, start=1):
    chunk["sentiment_score"] = chunk["clean_text"].apply(
        lambda x: analyzer.polarity_scores(str(x))["compound"]
    )

    if first_chunk:
        chunk.to_csv(output_path, index=False, mode="w")
        first_chunk = False
    else:
        chunk.to_csv(output_path, index=False, mode="a", header=False)

    print(f"✅ Saved chunk {i}")
# Out:
# ✅ Saved chunk 1
# ✅ Saved chunk 2
# ✅ Saved chunk 3
# ✅ Saved chunk 4
# ✅ Saved chunk 5
# ✅ Saved chunk 6
# ✅ Saved chunk 7
# ✅ Saved chunk 8
# ✅ Saved chunk 9
# ✅ Saved chunk 10
# ✅ Saved chunk 11
# ✅ Saved chunk 12
# ✅ Saved chunk 13
# ✅ Saved chunk 14
# ✅ Saved chunk 15
# ✅ Saved chunk 16
# ✅ Saved chunk 17
# ✅ Saved chunk 18
# ✅ Saved chunk 19
# ✅ Saved chunk 20
# ✅ Saved chunk 21
# ✅ Saved chunk 22
# ✅ Saved chunk 23
# ✅ Saved chunk 24
# ✅ Saved chunk 25
# ✅ Saved chunk 26
# ✅ Saved chunk 27
# ✅ Saved chunk 28
# ✅ Saved chunk 29

# %%
df = pd.read_csv("../data/mental_health_reddit_with_sentiment.csv")
df.shape
# Out:
# (570004, 6)
